# %% [markdown]
# <a href="https://colab.research.google.com/github/NevermindGust/IA_Python_Aulas/blob/main/panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#faz o upload do arquivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-440c8b33-101c-41b7-98ff-6fc8ea6e3d8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-440c8b33-101c-41b7-98ff-6fc8ea6e3d8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#mostra o nome e tamanho do arquivo
# !ls

for fn in uploaded.keys():
  print('Arquivo "{name}" com tamanho de {lenght} bytes'.format(name=fn, lenght=len(uploaded[fn])))
# Out:
# dados_20240319102150.xlsx  sample_data
# Arquivo "dados_20240319102150.xlsx" com tamanho de 7712 bytes

# %%
dados1 = pd.read_excel('dados.xlsx')
#mostra a estrutura da tabela
dados1.shape
# Out:
# (10, 2)

# %%
#mostra os elementos da tabela
dados1.head(3)
# Out:
#    números letras
# 0        1      a
# 1        2      b
# 2        3      c

# %%
#opção 1 - indicada pelo Pandas
uploaded.update(files.upload())
# Out:
#      <input type="file" id="files-6ca998a4-37c1-4f3b-b5b7-dd85342cdb4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ca998a4-37c1-4f3b-b5b7-dd85342cdb4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dados2 = pd.read_excel('basecensus.xlsx')

# %%
dados2.shape
# Out:
# (30162, 16)

# %%
dados2.head(8)

# %%
#dicionario de alunos
alunos = {'Nome': ['Marcelo', 'Lucas', 'Cynthia', 'Helena'],
          'Media': [4, 7, 5.5, 9],
          'Status': ['Reprovado', 'Aprovado', 'Reprovado', 'Aprovado']}

# %%
from re import A
#converter dicionario em dataframe
df1 = pd.DataFrame(alunos)
df1.shape
df1.head()

# %%
#mostra uma contagem com: num. de elementos, media, desvio padrão, 1°, 2° e 3° quartis...
df1.describe()
# Out:
#           Media
# count  4.000000
# mean   6.375000
# std    2.136001
# min    4.000000
# 25%    5.125000
# 50%    6.250000
# 75%    7.500000
# max    9.000000

# %%
#filtra uma coluna especifica
df1[["Nome"]]
# Out:
#       Nome
# 0  Marcelo
# 1    Lucas
# 2  Cynthia
# 3   Helena

# %%
#localiza dois elementos especificos
df1.loc[[0, 1]]
# Out:
#       Nome  Media     Status
# 0  Marcelo    4.0  Reprovado
# 1    Lucas    7.0   Aprovado

# %%
#localiza os elementos em um intervalo
df1.loc[1:3]
# Out:
#       Nome  Media     Status
# 1    Lucas    7.0   Aprovado
# 2  Cynthia    5.5  Reprovado
# 3   Helena    9.0   Aprovado

# %%
df1.loc[df1["Status"] == "Aprovado"]
# Out:
#      Nome  Media    Status
# 1   Lucas    7.0  Aprovado
# 3  Helena    9.0  Aprovado

# %%
df1.loc[df1["Media"] < 7.0]
# Out:
#       Nome  Media     Status
# 0  Marcelo    4.0  Reprovado
# 2  Cynthia    5.5  Reprovado

# %%
#salvar em uma variavel é uma boa pratica
exame = df1.loc[df1["Media"] < 7.0]
print(exame)
# Out:
#       Nome  Media     Status
# 0  Marcelo    4.0  Reprovado
# 2  Cynthia    5.5  Reprovado

# %%
dados2.loc[dados2["education"] == " Masters"]
# Out:
#        Unnamed: 0  age          workclass  final.weight education  \
# 5               6   37            Private        284582   Masters
# 8               9   31            Private         45781   Masters
# 18             20   43   Self-emp-not-inc        292175   Masters
# 44             48   44            Private        128354   Masters
# 80             88   33            Private        202051   Masters
# ...           ...  ...                ...           ...       ...
# 30112       32505   50            Private        208630   Masters
# 30120       32514   46            Private         42972   Masters
# 30145       32545   31            Private        199655   Masters
# 30154       32554   32            Private        116138   Masters
# 30155       32555   53            Private        321865   Masters
#
#        education.num       marital.status        occupation    relationship  \
# 5                 14   Married-civ-spouse   Exec-managerial            Wife
# ...
